# %%
import pandas as pd
from sqlalchemy import create_engine
from pyecharts.charts import Pie
from pyecharts import options as opts
from pyecharts.globals  import ThemeType

# %%
engine = create_engine('mysql+pymysql://root:123123@localhost:3306/bili')
sql = 'SELECT * FROM all_up_info'
df = pd.read_sql_query(sql, engine)
df
# Out:
#             uid             用户名  性别  等级   粉丝牌    大会员  \
# 0            75              丸子   男   6   云丸家  百年大会员
# 1          1492           Q-kun  保密   6  None  年度大会员
# 2          2776          HJISTC  保密   6  None  年度大会员
# 3          3506              车牌   男   6    胖丁  年度大会员
# 4          7349          STN工作室   男   6  None   None
# ..          ...             ...  ..  ..   ...    ...
# 369  1768771255           牧场小老板  保密   5  None  年度大会员
# 370  1868902080         哔哩哔哩拜年纪  保密   6  None   None
# 371  1883857209            来自星尘  保密   2  None  年度大会员
# 372  2026561407          吃花椒的喵酱  保密   6  None  年度大会员
# 373  2138676495  申䒕雅_小雅Official  保密   6  None  年度大会员
#
#                                      认证  关注数      粉丝数        获赞数  ...   资讯  \
# 0                 bilibili 知名UP主、直播高能主播  320  1010321  120157663  ...  NaN
# 1                       bilibili 直播高能主播   75   486038   64071002  ...  NaN
# 2                                  None   89    15210     933925  ...  NaN
# 3                                  None    9    59619   19013157  ...  NaN
# 4    bilibili 2019百大UP主、 知名游戏UP主、直播签约主播  124  1827637  396243280  ...  NaN
# ..                                  ...  ...      ...        ...  ...  ...
# 369                                None   27    18235     120984  ...  NaN
# 370                         哔哩哔哩拜年纪官方账号   21  4222908    7396358  ...  NaN
# 371                         来自星尘 手游官方账号    2   331160     111934  ...  NaN
# 372                              媒体人王冰冰   10  4827489   11523867  ...  3.0
# 373                     bilibili 直播签约主播  263    70179    3670201  ...  1.0
#
#        娱乐    影视   TV剧   放映厅  纪录片   运动   汽车  电视剧  电影
# 0     NaN   1.0  None  None  NaN  1.0  NaN  NaN NaN
# 1     NaN   NaN  None  None  NaN  NaN  NaN  NaN NaN
# 2     NaN   NaN  None  None  NaN  NaN  NaN  NaN NaN
# 3     NaN  40.0  None  None  NaN  NaN  NaN  NaN NaN
# 4     2.0  26.0  None  None  NaN  9.0  9.0  NaN NaN
# ..    ...   ...   ...   ...  ...  ...  ...  ...  ..
# 369   NaN   NaN  None  None  NaN  3.0  NaN  NaN NaN
# 370   NaN   NaN  None  None  NaN  NaN  NaN  NaN NaN
# 371   NaN   NaN  None  None  NaN  NaN  NaN  NaN NaN
# 372   NaN   NaN  None  None  NaN  1.0  NaN  NaN NaN
# 373  21.0   2.0  None  None  NaN  NaN  NaN  NaN NaN
#
# [374 rows x 36 columns]

# %%
# 生成基础饼图
def create_pie(text, title):
    data = df['{}'.format(text)].value_counts().to_dict()
    pie = (
        Pie(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
        .add("", [list(z) for z in zip(data.keys(), data.values())])
        .set_global_opts(title_opts=opts.TitleOpts(title="{}".format(title)))
    )
    return pie.render_notebook()

# %%
create_pie('大会员','大会员占比')
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="72e1c898d5af4e189970d271a75d46e4" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_72e1c898d5af4e189970d271a75d46e4 = echarts.init(
#             document.getElementById('72e1c898d5af4e189970d271a75d46e4'), 'light', {renderer: 'canvas'});
#         var option_72e1c898d5af4e189970d271a75d46e4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5e74\u5ea6\u5927\u4f1a\u5458",
#                     "value": 253
#                 },
#                 {
#                     "name": "\u5341\u5e74\u5927\u4f1a\u5458",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u5927\u4f1a\u5458",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u767e\u5e74\u5927\u4f1a\u5458",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e74\u5ea6\u5927\u4f1a\u5458",
#                 "\u5341\u5e74\u5927\u4f1a\u5458",
#                 "\u5927\u4f1a\u5458",
#                 "\u767e\u5e74\u5927\u4f1a\u5458"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u5927\u4f1a\u5458\u5360\u6bd4",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_72e1c898d5af4e189970d271a75d46e4.setOption(option_72e1c898d5af4e189970d271a75d46e4);
#     </script>
# </body>
# </html>

# %%
create_pie('性别','用户中性别占比')
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="69763f46fe0e4e19a3e2375faf6ac390" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_69763f46fe0e4e19a3e2375faf6ac390 = echarts.init(
#             document.getElementById('69763f46fe0e4e19a3e2375faf6ac390'), 'light', {renderer: 'canvas'});
#         var option_69763f46fe0e4e19a3e2375faf6ac390 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u4fdd\u5bc6",
#                     "value": 231
#                 },
#                 {
#                     "name": "\u7537",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u5973",
#                     "value": 43
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4fdd\u5bc6",
#                 "\u7537",
#                 "\u5973"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u7528\u6237\u4e2d\u6027\u522b\u5360\u6bd4",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_69763f46fe0e4e19a3e2375faf6ac390.setOption(option_69763f46fe0e4e19a3e2375faf6ac390);
#     </script>
# </body>
# </html>
